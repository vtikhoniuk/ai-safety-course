# %% [markdown]
# # Tutorial 2: Evaluating LLMs on MMLU
#
# Welcome to the second tutorial in our AI Safety Evaluations course.
#
# Benchmark evaluation is a core skill in applied ML, but the statistical side is often
# treated as an afterthought — a single accuracy number gets reported, and model differences
# are treated as real without checking whether they could arise from chance alone.
# In this tutorial you will get hands-on experience running evaluations with the inspect_ai
# library and applying basic statistical methods to interpret the results rigorously.
#
# **What you'll learn:**
#
# - Load and prepare a benchmark dataset
# - Compute confidence intervals for accuracy
# - Compare models statistically
# - Perform power analysis to plan evaluation size
#
# **By the end:** **You'll have a statistically rigorous evaluation pipeline that can tell you not just how accurate a model is, but whether observed differences between models are real.**

# %% [markdown]
# ## 1. Setup

# %%
# !pip install pandas matplotlib scipy
# !pip install datasets
# !pip install --upgrade inspect-ai


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from string import ascii_uppercase
from typing import Tuple, List

from inspect_ai import Task, task, eval
from inspect_ai.dataset import Sample, hf_dataset, FieldSpec
from inspect_ai.solver import multiple_choice
from inspect_ai.scorer import choice
from inspect_ai.log import EvalLog
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/vt/.local/lib/python3.11/site-packages (3.0.2)
# Requirement already satisfied: matplotlib in /home/vt/.local/lib/python3.11/site-packages (3.10.8)
# Requirement already satisfied: scipy in /home/vt/.local/lib/python3.11/site-packages (1.17.1)
# Requirement already satisfied: numpy>=1.26.0 in /home/vt/.local/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vt/.local/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/vt/.local/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/vt/.local/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vt/.local/lib/python3.11/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/vt/.local/lib/python3.11/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/vt/.local/lib/python3.11/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/vt/.local/lib/python3.11/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in /home/vt/.local/lib/python3.11/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datasets in /home/vt/.local/lib/python3.11/site-packages (4.8.4)
# Requirement already satisfied: filelock in /home/vt/.local/lib/python3.11/site-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /home/vt/.local/lib/python3.11/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=21.0.0 in /home/vt/.local/lib/python3.11/site-packages (from datasets) (23.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /home/vt/.local/lib/python3.11/site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pandas in /home/vt/.local/lib/python3.11/site-packages (from datasets) (3.0.2)
# Requirement already satisfied: requests>=2.32.2 in /home/vt/.local/lib/python3.11/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: httpx<1.0.0 in /home/vt/.local/lib/python3.11/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in /home/vt/.local/lib/python3.11/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /home/vt/.local/lib/python3.11/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in /home/vt/.local/lib/python3.11/site-packages (from datasets) (0.70.19)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in /home/vt/.local/lib/python3.11/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2025.9.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /home/vt/.local/lib/python3.11/site-packages (from datasets) (1.11.0)
# Requirement already satisfied: packaging in /home/vt/.local/lib/python3.11/site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/vt/.local/lib/python3.11/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/vt/.local/lib/python3.11/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.11.12)
# Requirement already satisfied: anyio in /home/vt/.local/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (4.8.0)
# Requirement already satisfied: certifi in /home/vt/.local/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /home/vt/.local/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (1.0.7)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from httpx<1.0.0->datasets) (3.3)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/vt/.local/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /home/vt/.local/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.4.3)
# Requirement already satisfied: typer in /home/vt/.local/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/vt/.local/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/vt/.local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/vt/.local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/lib/python3/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (21.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/vt/.local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/vt/.local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/vt/.local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/vt/.local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vt/.local/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.32.2->datasets) (1.26.5)
# Requirement already satisfied: sniffio>=1.1 in /home/vt/.local/lib/python3.11/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vt/.local/lib/python3.11/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: click>=8.2.1 in /home/vt/.local/lib/python3.11/site-packages (from typer->huggingface-hub<2.0,>=0.25.0->datasets) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/vt/.local/lib/python3.11/site-packages (from typer->huggingface-hub<2.0,>=0.25.0->datasets) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /home/vt/.local/lib/python3.11/site-packages (from typer->huggingface-hub<2.0,>=0.25.0->datasets) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/vt/.local/lib/python3.11/site-packages (from typer->huggingface-hub<2.0,>=0.25.0->datasets) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/vt/.local/lib/python3.11/site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.25.0->datasets) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/vt/.local/lib/python3.11/site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.25.0->datasets) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /home/vt/.local/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=0.25.0->datasets) (0.1.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: inspect-ai in /home/vt/.local/lib/python3.11/site-packages (0.3.207)
# Requirement already satisfied: aioboto3>=13.0.0 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (15.5.0)
# Requirement already satisfied: aiohttp>=3.9.0 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (3.11.12)
# Requirement already satisfied: anyio>=4.8.0 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (4.8.0)
# Requirement already satisfied: beautifulsoup4>=4.10.0 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (4.13.3)
# Requirement already satisfied: boto3 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (1.40.61)
# Requirement already satisfied: click!=8.2.0,<8.2.2,>=8.1.3 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (8.2.1)
# Requirement already satisfied: debugpy in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (1.8.20)
# Requirement already satisfied: docstring-parser>=0.16 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (0.18.0)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (2025.9.0)
# Requirement already satisfied: httpx in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (0.28.1)
# Requirement already satisfied: ijson>=3.2.0 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (3.5.0)
# Requirement already satisfied: jsonlines>=3.0.0 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (4.0.0)
# Requirement already satisfied: jsonpatch>=1.32 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (1.33)
# Requirement already satisfied: jsonpath-ng>=1.8.0 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (1.8.0)
# Requirement already satisfied: jsonref>=1.1.0 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (1.1.0)
# Requirement already satisfied: jsonschema>3.1.1 in /usr/lib/python3/dist-packages (from inspect-ai) (3.2.0)
# Requirement already satisfied: mmh3>3.1.0 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (5.2.1)
# Requirement already satisfied: nest_asyncio2>=1.7.2 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (1.7.2)
# Requirement already satisfied: numpy in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (1.26.4)
# Requirement already satisfied: platformdirs>=2.3.0 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (4.3.6)
# Requirement already satisfied: psutil in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (7.2.2)
# Requirement already satisfied: pydantic>=2.13.0 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (2.13.2)
# Requirement already satisfied: python-dotenv>=0.16.0 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (1.0.1)
# Requirement already satisfied: pyyaml in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (6.0.2)
# Requirement already satisfied: rich!=14.0.0,>=13.3.3 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (15.0.0)
# Requirement already satisfied: s3fs>=2023 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (2025.9.0)
# Requirement already satisfied: semver>=3.0.0 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (3.0.4)
# Requirement already satisfied: shortuuid in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (1.0.13)
# Requirement already satisfied: sniffio in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (1.3.1)
# Requirement already satisfied: tenacity in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (9.0.0)
# Requirement already satisfied: textual>=2.1.0 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (8.2.3)
# Requirement already satisfied: tiktoken>=0.12.0 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (0.12.0)
# Requirement already satisfied: typing_extensions>=4.14.0 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (4.15.0)
# Requirement already satisfied: universal-pathlib>=0.2.6 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (0.3.10)
# Requirement already satisfied: zipfile-zstd>=0.0.4 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (0.0.4)
# Requirement already satisfied: zipp>=3.19.1 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (3.23.1)
# Requirement already satisfied: zstandard>=0.20.0 in /home/vt/.local/lib/python3.11/site-packages (from inspect-ai) (0.23.0)
# Requirement already satisfied: aiobotocore==2.25.1 in /home/vt/.local/lib/python3.11/site-packages (from aiobotocore[boto3]==2.25.1->aioboto3>=13.0.0->inspect-ai) (2.25.1)
# Requirement already satisfied: aiofiles>=23.2.1 in /home/vt/.local/lib/python3.11/site-packages (from aioboto3>=13.0.0->inspect-ai) (25.1.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /home/vt/.local/lib/python3.11/site-packages (from aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3>=13.0.0->inspect-ai) (0.13.0)
# Requirement already satisfied: botocore<1.40.62,>=1.40.46 in /home/vt/.local/lib/python3.11/site-packages (from aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3>=13.0.0->inspect-ai) (1.40.61)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/vt/.local/lib/python3.11/site-packages (from aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3>=13.0.0->inspect-ai) (2.9.0.post0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/vt/.local/lib/python3.11/site-packages (from aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3>=13.0.0->inspect-ai) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /home/vt/.local/lib/python3.11/site-packages (from aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3>=13.0.0->inspect-ai) (6.1.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /home/vt/.local/lib/python3.11/site-packages (from aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3>=13.0.0->inspect-ai) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/vt/.local/lib/python3.11/site-packages (from aiohttp>=3.9.0->inspect-ai) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/vt/.local/lib/python3.11/site-packages (from aiohttp>=3.9.0->inspect-ai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/lib/python3/dist-packages (from aiohttp>=3.9.0->inspect-ai) (21.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/vt/.local/lib/python3.11/site-packages (from aiohttp>=3.9.0->inspect-ai) (1.5.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/vt/.local/lib/python3.11/site-packages (from aiohttp>=3.9.0->inspect-ai) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/vt/.local/lib/python3.11/site-packages (from aiohttp>=3.9.0->inspect-ai) (1.18.3)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /home/vt/.local/lib/python3.11/site-packages (from boto3->inspect-ai) (0.14.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/lib/python3/dist-packages (from botocore<1.40.62,>=1.40.46->aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3>=13.0.0->inspect-ai) (1.26.5)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3>=13.0.0->inspect-ai) (1.16.0)
# Requirement already satisfied: idna>=2.0 in /usr/lib/python3/dist-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.9.0->inspect-ai) (3.3)
# Requirement already satisfied: soupsieve>1.2 in /home/vt/.local/lib/python3.11/site-packages (from beautifulsoup4>=4.10.0->inspect-ai) (2.6)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/lib/python3/dist-packages (from jsonpatch>=1.32->inspect-ai) (2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/vt/.local/lib/python3.11/site-packages (from pydantic>=2.13.0->inspect-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.2 in /home/vt/.local/lib/python3.11/site-packages (from pydantic>=2.13.0->inspect-ai) (2.46.2)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/vt/.local/lib/python3.11/site-packages (from pydantic>=2.13.0->inspect-ai) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/vt/.local/lib/python3.11/site-packages (from rich!=14.0.0,>=13.3.3->inspect-ai) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/vt/.local/lib/python3.11/site-packages (from rich!=14.0.0,>=13.3.3->inspect-ai) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /home/vt/.local/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich!=14.0.0,>=13.3.3->inspect-ai) (0.1.2)
# Requirement already satisfied: mdit-py-plugins in /home/vt/.local/lib/python3.11/site-packages (from textual>=2.1.0->inspect-ai) (0.5.0)
# Requirement already satisfied: linkify-it-py<3,>=1 in /home/vt/.local/lib/python3.11/site-packages (from markdown-it-py[linkify]>=2.1.0->textual>=2.1.0->inspect-ai) (2.1.0)
# Requirement already satisfied: uc-micro-py in /home/vt/.local/lib/python3.11/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.1.0->textual>=2.1.0->inspect-ai) (2.0.0)
# Requirement already satisfied: regex>=2022.1.18 in /home/vt/.local/lib/python3.11/site-packages (from tiktoken>=0.12.0->inspect-ai) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /home/vt/.local/lib/python3.11/site-packages (from tiktoken>=0.12.0->inspect-ai) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vt/.local/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken>=0.12.0->inspect-ai) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vt/.local/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken>=0.12.0->inspect-ai) (2026.2.25)
# Requirement already satisfied: pathlib-abc<0.6.0,>=0.5.1 in /home/vt/.local/lib/python3.11/site-packages (from universal-pathlib>=0.2.6->inspect-ai) (0.5.2)
# Requirement already satisfied: httpcore==1.* in /home/vt/.local/lib/python3.11/site-packages (from httpx->inspect-ai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/vt/.local/lib/python3.11/site-packages (from httpcore==1.*->httpx->inspect-ai) (0.14.0)

# %%
# Configure models -- replace with what is available in your environment.
# Examples: 'ollama/llama3.2', 'openai/gpt-4o-mini', 'anthropic/claude-haiku-4-5'

# Using OpenRouter — set OPENROUTER_API_KEY env var first.
MODEL_A = "openrouter/qwen/qwen-2.5-7b-instruct"        # weaker / baseline model
MODEL_B = "openrouter/qwen/qwen-2.5-72b-instruct"       # stronger / comparison model

# %% [markdown]
# ## 2. Loading MMLU
#
# `hf_dataset` is inspect_ai's loader for Hugging Face datasets. It downloads the data
# and wraps each record in a `Sample` -- the standard container that flows through every
# inspect_ai pipeline. A `Sample` carries the model input, the expected target, optional
# answer choices, and arbitrary metadata you want to keep around.
#
# MMLU stores the correct answer as an integer (0 = A, 1 = B, 2 = C, 3 = D).
# The quickest way to load a dataset is with `FieldSpec`, which maps column names to
# `Sample` fields. Let's try it first and see what we get.

# %%
dataset_raw = hf_dataset(
    path="cais/mmlu",
    name="all",
    split="test",
    sample_fields=FieldSpec(
        input="question",
        target="answer",           # raw MMLU answer is an integer index 0-3
        metadata=["choices", "subject"]
    ),
    cached=True
)

sample = dataset_raw[0]
print("input   :", sample.input[:80], "...")
print("target  :", sample.target,  "  <- integer index, not a letter!")
print("choices :", sample.metadata.get("choices"))
# Out:
# input   : Find the degree for the given field extension Q(sqrt(2), sqrt(3), sqrt(18)) over ...
# target  : 1   <- integer index, not a letter!
# choices : ['0', '4', '2', '6']

# %% [markdown]
# The `target` came out as an integer -- but inspect_ai's `multiple_choice()` solver
# and `choice()` scorer expect it to be a letter (`"A"`, `"B"`, `"C"`, or `"D"`).
# When the automatic mapping isn't enough, inspect_ai lets you pass a
# **record-to-sample function** that receives the full raw record and returns a `Sample`
# you construct yourself.

# %%
def record_to_sample(record: dict) -> Sample:
    """
    Convert a raw MMLU record to an inspect_ai Sample.

    MMLU stores the correct answer as an integer index (0=A, 1=B, 2=C, 3=D).
    We convert it to the corresponding uppercase letter so it matches the
    format expected by the choice() scorer.
    """
    answer_idx = int(record["answer"])
    return Sample(
        input=record["question"],
        choices=record["choices"],
        target=ascii_uppercase[answer_idx],   # 0->'A', 1->'B', ...
        metadata=dict(subject=record.get("subject"))
    )


dataset = hf_dataset(
    path="cais/mmlu",
    name="all",
    split="test",
    sample_fields=record_to_sample,
    cached=True
)

sample = dataset[0]
print("target  :", sample.target, " <- letter now")
print("choices :", sample.choices)
# Out:
# target  : B  <- letter now
# choices : ['0', '4', '2', '6']

# %% [markdown]
# ## Assignment 1: Create your working subset
#
# All experiments in this notebook will run on a subject subset small enough to evaluate
# quickly. `Dataset.filter()` takes a predicate over `Sample` objects; the `metadata`
# field gives access to anything set in `record_to_sample` -- here, the MMLU subject tag.
#
# We define `astronomy_subset` as a reference example. Pick any subject or subjects from the [MMLU subject list](https://huggingface.co/datasets/cais/mmlu#task-descriptions) with at least 50 questions so later analyses are statistically meaningful. Create MY_SUBSET and use it in all subsequent exercises.

# %%
# Reference subset used in worked examples
astronomy_subset = dataset.filter(
    lambda s: s.metadata.get("subject") == "astronomy"
)
print(f"Astronomy: {len(astronomy_subset)} questions")


MY_SUBSET = dataset.filter(
    lambda s: s.metadata.get("subject") == "machine_learning"
)

print(f"My subset: {len(MY_SUBSET)} questions")
# Out:
# Astronomy: 152 questions
# My subset: 112 questions

# %% [markdown]
# ## 3. Running an evaluation
#
# Every inspect_ai evaluation is described by a `Task`, which bundles three things:
#
# - **dataset** -- the questions
# - **solver** -- the chain of steps that produces a model response;
#   `multiple_choice()` formats the prompt with lettered options and parses the model's choice
# - **scorer** -- the function that grades the response;
#   `choice()` checks whether the selected letter matches the target
#
# The `@task` decorator registers the function so inspect_ai can discover it by name
# from the CLI or pass it directly to `eval()`.

# %%
@task
def mmlu_subset(subset):
    """Minimal MMLU task for any subject subset."""
    return Task(
        dataset=subset,
        solver=[multiple_choice()],
        scorer=choice()
    )

# %% [markdown]
# Calling `eval()` runs the task and returns a **list of `EvalLog` objects** -- one per
# (task, model) pair. Everything you need is in this object; there is no need to read
# log files from disk.
#
# The two most useful attributes:
# - `log.results.scores` -- list of scorer results, each with a `metrics` dict
#   (`"accuracy"`, `"stderr"`, etc.)
# - `log.samples` -- list of `EvalSample` objects with per-question inputs, outputs, and scores

# %%
logs: List[EvalLog] = eval(
    mmlu_subset(astronomy_subset),
    model=MODEL_A,
    limit=10        # evaluate only the first 10 questions
)

log = logs[0]      # one task -> one log
print("Status  :", log.status)
print("Model   :", log.eval.model)
print("Accuracy:", log.results.scores[0].metrics["accuracy"].value)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Status  : success
# Model   : openrouter/qwen/qwen-2.5-7b-instruct
# Accuracy: 1.0

# %% [markdown]
# ## 4. From `EvalLog` to a DataFrame
#
# ## Assignment 2: Implement `log_to_df`
#
# The aggregate accuracy in `log.results` is useful for a quick check, but for the
# statistical analyses ahead we need a flat table: **one row per (question, epoch)**
# with a numeric `score` column.
#
# `log.samples` is a list of `EvalSample` objects. Each one has:
# - `.id` -- question identifier
# - `.epoch` -- which run this belongs to (relevant when `epochs > 1`)
# - `.scores` -- a dict mapping scorer name to `Score`; the `Score.value` for `choice()` is
#   `"C"` (correct) or `"I"` (incorrect)
# - `.metadata` -- the metadata dict you set in `record_to_sample`
#
# Implement `log_to_df` so that it converts an `EvalLog` into a DataFrame with columns
# `id`, `epoch`, `score` (1/0), and `subject`. The smoke test below will verify the shape.

# %%
def log_to_df(log: EvalLog) -> pd.DataFrame:
    rows = []
    for sample in log.samples:
        rows.append({
            "id": sample.id,
            "epoch": sample.epoch,
            "score": 1 if sample.scores["choice"].value == "C" else 0,
            "subject": sample.metadata.get("subject"),
        })
    return pd.DataFrame(rows)


# =================================== TESTS ===================================
df_test = log_to_df(log)

assert set(df_test.columns) >= {"id", "epoch", "score", "subject"}
assert df_test["score"].isin([0, 1]).all()
assert len(df_test) == 10

print(df_test.head())
print(f"\nAccuracy: {df_test['score'].mean():.1%}")
# Out:
#    id  epoch  score    subject
# 0   1      1      1  astronomy
# 1   2      1      1  astronomy
# 2   3      1      1  astronomy
# 3   4      1      1  astronomy
# 4   5      1      1  astronomy
#
# Accuracy: 100.0%

# %% [markdown]
# ## 5. Confidence intervals
#
#
# A single accuracy number carries uncertainty: the eval used a finite set of questions
# sampled from a much larger space. The paper (ss2.1, ss3.1) shows how to quantify this
# using the CLT standard error.
#
#
# ## Assignment 3: Implement `ci_accuracy_basic` and `ci_accuracy`
#
# **`ci_accuracy_basic(scores, ci)`** -- the simple case where every question is answered
# exactly once. `scores` is a plain numpy array of 0s and 1s. Use Eq. 1 from the paper.
#
# **`ci_accuracy(df, ci)`** -- the general case that handles multiple runs per question
# (`epochs > 1`). When K runs exist for a question, average their scores first, then
# compute the SE across question-level averages. Pooling all K×n individual answers
# would undercount variance -- answers to the same question across epochs are correlated.

# %%
def ci_accuracy_basic(scores: np.ndarray, ci: float = 0.95) -> Tuple[float, float, float]:
    n = len(scores)
    p = np.mean(scores)
    z = stats.norm.ppf(1 - (1 - ci) / 2)
    se = np.sqrt(p * (1 - p) / n)
    return (p - z * se, p, p + z * se)


def ci_accuracy(df: pd.DataFrame, ci: float = 0.95) -> Tuple[float, float, float]:
    q_means = df.groupby("id")["score"].mean().values
    n = len(q_means)
    p = np.mean(q_means)
    z = stats.norm.ppf(1 - (1 - ci) / 2)
    se = np.std(q_means, ddof=0) / np.sqrt(n)
    return (p - z * se, p, p + z * se)

# %%
# =================================== TESTS ===================================
def _make_df(ids, scores, epochs=None):
    if epochs is None:
        epochs = [0] * len(ids)
    return pd.DataFrame({"id": ids, "score": scores, "epoch": epochs})

# ci_accuracy_basic
l, m, u = ci_accuracy_basic(np.ones(10))

assert l == 1.0 and u == 1.0, "perfect accuracy: CI should collapse to 1"

l, m, u = ci_accuracy_basic(np.zeros(10))

assert l == 0.0 and u == 0.0, "zero accuracy: CI should collapse to 0"

scores3 = np.array([1, 1, 0, 1, 0], dtype=float)
l, m, u = ci_accuracy_basic(scores3)

assert l < 0.6 < u, f"0.6 not in [{l:.3f}, {u:.3f}]"

np.random.seed(42)
s = np.random.binomial(1, 0.75, 200).astype(float)
l95, _, u95 = ci_accuracy_basic(s, 0.95)
l99, _, u99 = ci_accuracy_basic(s, 0.99)

assert (u99 - l99) > (u95 - l95), "99% CI must be wider than 95%"
assert np.isclose(l95, 0.6819421067148456, atol=10e-2)
assert np.isclose(u95, 0.8080578932851544, atol=10e-2)

# ci_accuracy (K=1 should match basic)
df3 = _make_df([1,2,3,4,5], scores3.tolist())
l_df, _, u_df = ci_accuracy(df3)
l_ar, _, u_ar = ci_accuracy_basic(scores3)

assert np.isclose(l_df, l_ar) and np.isclose(u_df, u_ar), "K=1 must match basic version"

# ci_accuracy (K=3 should give narrower CI on average)
np.random.seed(0)
rows_k1, rows_k3 = [], []
for q in range(30):
    p = np.random.uniform(0.3, 0.9)
    rows_k1.append({"id": q, "score": int(np.random.binomial(1, p)), "epoch": 0})
    for e in range(3):
        rows_k3.append({"id": q, "score": int(np.random.binomial(1, p)), "epoch": e})

l1, _, u1 = ci_accuracy(pd.DataFrame(rows_k1))
l3, _, u3 = ci_accuracy(pd.DataFrame(rows_k3))
print(f"K=1 width: {u1-l1:.3f}")
print(f"K=3 width: {u3-l3:.3f}  (narrower on average)")
print("\n✓ All tests passed!")
# Out:
# K=1 width: 0.337
# K=3 width: 0.223  (narrower on average)
#
# ✓ All tests passed!

# %% [markdown]
# ## 6. Visualising how CIs shrink
#
# Two things make confidence intervals narrower: more questions (larger n) and more
# runs per question (larger K). Your task is to visualise those effects.
#
# ## Assignment 4.1: Plot CI width vs number of epochs

# %%
k_values    = [5, 6, 7, 8, 9, 10]
accuracies    = []
ci_lowers     = []
ci_uppers     = []

for k in k_values:
    logs = eval(mmlu_subset(MY_SUBSET), model=MODEL_A, epochs=k)
    df = log_to_df(logs[0])
    lower, acc, upper = ci_accuracy(df)
    accuracies.append(acc)
    ci_lowers.append(lower)
    ci_uppers.append(upper)


plt.figure(figsize=(8, 4))
plt.fill_between(k_values, ci_lowers, ci_uppers, alpha=0.25, label="95% CI")
plt.plot(k_values, accuracies, "o-", lw=2, label="Accuracy")
plt.xlabel("Number of runs per question (K)")
plt.ylabel("Accuracy")
plt.title(f"{MODEL_A} on MMLU-subset — accuracy and CI vs k")
plt.legend()
plt.grid(True, alpha=0.4)
plt.tight_layout()
plt.show()
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ---
# 1. Look at how fast the band narrows.
#    At what point does running another epoch stop being worth it?
# 2. Does more K change your estimate of the model's accuracy, or just your confidence in it?
# 3. What does this tell you about how to allocate your evaluation budget?
#
# **Your answer:**
# 1. Returns drop off fast — after K≈5 the band barely moves, since ω² (between-question variance) doesn't shrink with K.
# 2. The point estimate stabilizes after a couple of epochs; extra K only narrows the CI.
# 3. Spend budget on more questions, not more repeats — n reduces both variance components, K only the within-question one.

# %% [markdown]
# ## Assignment 4.2: Compute and plot CI width vs n
#
# For each sample size n in `range(10, len(question_ids)+1, 10)`, slice both DataFrames
# to the first n question IDs, compute `ci_accuracy`, and record the CI width.
# Then plot width vs n.

# %%
# Run one eval on the full subset (or reuse a DataFrame from 4.1)
logs_full = eval(mmlu_subset(MY_SUBSET), model=MODEL_A)
df_full = log_to_df(logs_full[0])

question_ids = df_full["id"].unique()
dataset_sizes = range(10, len(question_ids) + 1, 10)
accuracies    = []
ci_lowers     = []
ci_uppers     = []

for n in dataset_sizes:
    df_slice = df_full[df_full["id"].isin(question_ids[:n])]
    lower, acc, upper = ci_accuracy(df_slice)
    accuracies.append(acc)
    ci_lowers.append(lower)
    ci_uppers.append(upper)


plt.figure(figsize=(8, 4))
plt.fill_between(dataset_sizes, ci_lowers, ci_uppers, alpha=0.25, label="95% CI")
plt.plot(dataset_sizes, accuracies, "o-", lw=2, label="Accuracy")
plt.xlabel("Number of questions (n)")
plt.ylabel("Accuracy")
plt.title(f"{MODEL_A} on MMLU-subset — accuracy and CI vs n")
plt.legend()
plt.grid(True, alpha=0.4)
plt.tight_layout()
plt.show()
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ---
# 1. At what n does the accuracy line start to feel stable?
# 2. Compare that number to the size of `MY_SUBSET` — are you in the reliable region?
# 3. Compare this curve to the one in 4.1. What is the difference in what K and n actually buy you?
#
# **Your answer:**
# 1. Typically around n≈50–80 the accuracy line flattens and the CI becomes tight enough to be informative.
# 2. MY_SUBSET has 112 questions, so yes — we're in the reliable region, though not with much headroom.
# 3. n shrinks both ω²/n and σ²/(nK), so it buys you a better estimate and tighter CI; K only shrinks σ²/(nK), so it only buys confidence against per-run noise.

# %% [markdown]
# ## 7. Comparing two models
#
# Reporting two accuracy numbers side by side doesn't tell you whether the gap is real
# or just noise. The paper (§4.2) describes a **paired test**: because both models answer
# the same questions, you can compute per-question score differences and test whether
# their mean differs significantly from zero. This removes question-difficulty variance
# and yields a lower standard error than treating the two runs as independent samples.

# %% [markdown]
# ## Assignment 5: Compare two models
#
# `run_and_get_scores` and `compare_models_paired` are provided. Complete
# `significance_by_paired_ttest` and use it to compare the two models on `MY_SUBSET`.
#
# Implement `significance_by_paired_ttest` and compare MODEL_A and MODEL_B.

# %%
def run_and_get_scores(model_name: str, dataset, epochs: int = 1) -> np.ndarray:
    """Run eval and return mean-per-question scores, sorted by question id."""
    print(f"  Running {model_name} ...")
    run_logs = eval(mmlu_subset(dataset), model=model_name, epochs=epochs)
    df = log_to_df(run_logs[0])
    return df.groupby("id")["score"].mean().sort_index().values


def significance_by_paired_ttest(
    scores1: np.ndarray,
    scores2: np.ndarray,
    alpha: float = 0.05,
    two_tailed: bool = True,
) -> Tuple[float, float, bool]:
    """
    Paired t-test between two sets of per-question scores.

    Returns (p_value, mean_difference scores1 - scores2, is_significant).
    """
    assert len(scores1) == len(scores2), "arrays must cover the same questions"
    
    alternative = "two-sided" if two_tailed else "greater"
    
    _, p_value = stats.ttest_rel(scores1, scores2, alternative=alternative)
    mean_diff  = float(np.mean(scores1 - scores2))
    
    return p_value, mean_diff, bool(p_value < alpha)


def compare_models_paired(
    model_a: str,
    model_b: str,
    dataset,
    alpha: float = 0.05,
    two_tailed: bool = True,
    epochs_a: int = 1,
    epochs_b: int = 1,
) -> Tuple[float, float, bool]:
    """
    Evaluate both models on the same dataset and run a paired t-test.

    Returns (p_value, mean_difference A - B, is_significant).
    """
    scores_a = run_and_get_scores(model_a, dataset, epochs=epochs_a)
    scores_b = run_and_get_scores(model_b, dataset, epochs=epochs_b)
    return significance_by_paired_ttest(scores_a, scores_b, alpha, two_tailed)

# %%
# =================================== TESTS ===================================
p, d, sig = significance_by_paired_ttest(np.array([1,2,3]), np.array([1,2,3]))

assert np.isclose(d, 0.0) and not sig

p, d, sig = significance_by_paired_ttest(
    np.array([1,1,1,1,1]), np.array([0,0,0,0,0]), two_tailed=False
)

assert sig and d > 0

print("All tests passed!")
# Out:
# All tests passed!
# /home/vt/.local/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:430: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return hypotest_fun_in(*args, **kwds)

# %%
p_value, mean_diff, is_sig = compare_models_paired(MODEL_A, MODEL_B, MY_SUBSET)

print(f"mean diff (A − B): {mean_diff:+.3f}")
print(f"p-value          : {p_value:.4f}")
print(f"significant @5%  : {is_sig}")
# Out:
# Output()
#   Running openrouter/qwen/qwen-2.5-7b-instruct ...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
#   Running openrouter/qwen/qwen-2.5-72b-instruct ...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# mean diff (A − B): -0.188
# p-value          : 0.0001
# significant @5%  : True

# %% [markdown]
# ---
# 1. Write down the p-value and the mean difference you got.
# 2. Is the gap significant? Is it large enough to matter in practice?
# 3. What would change your conclusion: more questions, a different subject, or a different model pair?
#
# **Your answer:**
# 1. p-value ≈ <fill in>, mean diff (A − B) ≈ <fill in> — 72B should beat 7B by roughly 10–20 pp on MMLU-ML.
# 2. A gap of that size with n=112 easily clears α=0.05; and 10+ pp is practically meaningful.
# 3. More questions would tighten the CI and detect smaller gaps; a different subject might shrink or flip the gap; a closer model pair (e.g. 7B vs 14B) could easily become non-significant on this n.

# %% [markdown]
# ## 8. Interval estimation of the accuracy difference
#
# In Assignment 5 you got a yes/no significance decision. Here you will estimate the size of the gap and its uncertainty: a confidence interval on the difference gives both pieces of information at once.
#
# ## Assignment 6: Estimate the accuracy gap
#
# Implement `ci_accuracy_for_difference` to compute a 95% CI on the per-question score differences.
#
# Compute and report the confidence interval on MODEL_A − MODEL_B.

# %%
def ci_accuracy_for_difference(
    scores1: np.ndarray, scores2: np.ndarray, ci: float = 0.95
) -> Tuple[float, float, float]:
    diffs = scores1 - scores2
    n = len(diffs)
    mean = float(np.mean(diffs))
    z = stats.norm.ppf(1 - (1 - ci) / 2)
    se = np.std(diffs, ddof=1) / np.sqrt(n)
    return (mean - z * se, mean, mean + z * se)


scores_a = run_and_get_scores(MODEL_A, MY_SUBSET)
scores_b = run_and_get_scores(MODEL_B, MY_SUBSET)

lo, mean, hi = ci_accuracy_for_difference(scores_a, scores_b)
print(f"MODEL_A − MODEL_B: {mean:+.3f}  95% CI: [{lo:+.3f}, {hi:+.3f}]")
# Out:
# Output()
#   Running openrouter/qwen/qwen-2.5-7b-instruct ...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#   Running openrouter/qwen/qwen-2.5-72b-instruct ...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# MODEL_A − MODEL_B: -0.241  95% CI: [-0.341, -0.141]

# %% [markdown]
# ---
# 1. Write down the interval. Does it contain zero?
# 2. How does this relate to the significance test in Assignment 5 — do they tell the same story?
# 3. Which result is more informative — the p-value or the interval? Why?
#
# **Your answer:**
# 1. 95% CI on A − B ≈ [-0.341, -0.141] — if 72B really beats 7B, it won't contain zero.
# 2. The interval excludes zero iff the two-tailed paired test rejects at α=0.05.
# 3. The interval — it reports both direction and magnitude with uncertainty, while the p-value only says "yes/no at this threshold".

# %% [markdown]
# ## 9. Power analysis
#
# Before running an expensive evaluation, it is worth asking: how many questions do we
# need to detect a meaningful difference with adequate statistical power?
# The paper (§5) derives the minimum detectable effect as a function of sample size n,
# question-level variance ω², and within-model variance σ².
#
# ## Assignment 7: 'Estimate variance components'
#
# Implement `estimate_variance_components` and report the MDE for `MY_SUBSET` at α = 0.05, power = 80%.

# %%
def estimate_variance_components(logs_a, logs_b):
    df_a = log_to_df(logs_a[0])
    df_b = log_to_df(logs_b[0])

    # Within-question (per-model) variance — needs epochs >= 2
    sigma2_a = float(df_a.groupby("id")["score"].var(ddof=1).mean())
    sigma2_b = float(df_b.groupby("id")["score"].var(ddof=1).mean())

    # Per-question mean differences
    mean_a = df_a.groupby("id")["score"].mean()
    mean_b = df_b.groupby("id")["score"].mean()
    common = mean_a.index.intersection(mean_b.index)
    d = (mean_a.loc[common] - mean_b.loc[common]).values

    ka = df_a.groupby("id").size().mean()
    kb = df_b.groupby("id").size().mean()

    # Subtract within-question noise contribution to isolate true question-level effect
    omega2 = float(np.var(d, ddof=1) - sigma2_a / ka - sigma2_b / kb)
    omega2 = max(omega2, 0.0)

    return {"omega2": omega2, "sigma2_a": sigma2_a, "sigma2_b": sigma2_b}



def minimum_detectable_effect(
    n: int,
    omega2: float,
    sigma2_a: float = 0.0,
    sigma2_b: float = 0.0,
    ka: int = 1,
    kb: int = 1,
    alpha: float = 0.05,
    power: float = 0.80,
) -> float:
    """MDE for a paired model comparison (Eq. 10 in the paper)."""
    z_alpha = stats.norm.ppf(1 - alpha / 2)
    z_beta  = stats.norm.ppf(power)
    return float((z_alpha + z_beta) * np.sqrt(
        (omega2 + sigma2_a / ka + sigma2_b / kb) / n
    ))

# %%
print("Running pilot evals ...")
logs_a = eval(mmlu_subset(MY_SUBSET), model=MODEL_A, epochs=2, limit=15)
logs_b = eval(mmlu_subset(MY_SUBSET), model=MODEL_B, epochs=2, limit=15)

params = estimate_variance_components(logs_a, logs_b)
print(f"omega2  = {params['omega2']:.4f}")
print(f"sigma2_A = {params['sigma2_a']:.4f}")
print(f"sigma2_B = {params['sigma2_b']:.4f}")

mde = minimum_detectable_effect(n=len(MY_SUBSET), **params)
print(f"\nWith n={len(MY_SUBSET)} questions -> MDE = {mde:.1%}")
print("(smallest gap detectable at 80% power, alpha=0.05)")
# Out:
# Output()
# Running pilot evals ...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# omega2  = 0.0000
# sigma2_A = 0.0333
# sigma2_B = 0.0667
#
# With n=112 questions -> MDE = 8.4%
# (smallest gap detectable at 80% power, alpha=0.05)

# %% [markdown]
# ---
# 1. What MDE did you get for `MY_SUBSET`? Is that gap practically meaningful?
# 2. If the MDE is larger than the gap you observed in Assignment 5,
#    what does that say about your earlier result?
#
# **Your answer:**
# 1. MDE ≈ 8.4% (typically ~8–12% for n=112 on a noisy MMLU subset) — only large gaps are detectable, so small practical differences would be missed.
# 4. It means you were underpowered: a "non-significant" result doesn't prove the models are equal, it just says your n was too small to detect a gap of that size.

# %% [markdown]
# ## Assignment 8: Implement `required_sample_size`
#
# `minimum_detectable_effect` computes delta given n. Implement its inverse:
# given a target delta, return the minimum n needed. Use the sample-size formula
# from ss5 of the paper (Eq. 9). Verify it passes the round-trip check,
# then use it to compute how many questions you would need to detect a 5% and a 10%
# accuracy gap on `MY_SUBSET`.

# %%
# --- Assignment 7 -----------------------------------------------------------
def required_sample_size(
    delta: float,
    omega2: float,
    sigma2_a: float = 0.0,
    sigma2_b: float = 0.0,
    ka: int = 1,
    kb: int = 1,
    alpha: float = 0.05,
    power: float = 0.80,
) -> int:
    """Minimum number of questions needed to detect `delta` at the given power."""
    z_alpha = stats.norm.ppf(1 - alpha / 2)
    z_beta  = stats.norm.ppf(power)
    n = (z_alpha + z_beta) ** 2 * (omega2 + sigma2_a / ka + sigma2_b / kb) / delta ** 2
    return int(np.ceil(n))



# =================================== TESTS ===================================
n_needed = required_sample_size(delta=0.05, **params)
print(f"Questions needed to detect delta=5%: {n_needed}")

mde_check = minimum_detectable_effect(n=n_needed, **params)

assert abs(mde_check - 0.05) < 0.005, f"Round-trip failed: MDE={mde_check:.3f}"

print("Round-trip check passed!")
# Out:
# Questions needed to detect delta=5%: 314
# Round-trip check passed!

# %%
for delta in [0.05, 0.10]:
    n = required_sample_size(delta=delta, **params)
    print(f"To detect delta={delta:.0%}: n = {n} questions  (MY_SUBSET has {len(MY_SUBSET)})")
# Out:
# To detect delta=5%: n = 314 questions  (MY_SUBSET has 112)
# To detect delta=10%: n = 79 questions  (MY_SUBSET has 112)

# %% [markdown]
# ---
# 1. How many questions do you need to detect a 5% gap? A 10% gap?
# 2. Does `MY_SUBSET` have enough questions to be a useful benchmark for comparing these two models?
#
# **Your answer:**
# 1. Roughly n ≈ 314 for 5% and n ≈ 79 for 10% — the 5% target usually needs ~4× more questions than the 10% target (since n scales as 1/δ²).
# 2. For a 10% gap - yes; for a 5% gap, 112 questions is almost certainly too few — you'd need a larger subset or multiple MMLU subjects combined.

# %% [markdown]
# ## Assignment 9: Compare a model with itself: baseline vs chain-of-thought
#
# The `multiple_choice()` solver we have used so far prompts the model to answer
# directly. inspect_ai also provides a `chain_of_thought` that asks the model
# to reason step by step before giving its final answer.
#
# Using the paired comparison infrastructure from Section 7, evaluate the same model
# twice on the same subset — once with the default solver and once with
# `chain_of_thought` — and test whether the difference in accuracy is statistically
# significant. Does reasoning help? Is the effect consistent across subjects?

# %%
@task
def mmlu_cot(subset):
    return Task(
        dataset=subset,
        solver=[multiple_choice(cot=True)],
        scorer=choice()
    )

logs_plain = eval(mmlu_subset(MY_SUBSET), model=MODEL_A)
logs_cot   = eval(mmlu_cot(MY_SUBSET),    model=MODEL_A)

scores_plain = log_to_df(logs_plain[0]).groupby("id")["score"].mean().sort_index().values
scores_cot   = log_to_df(logs_cot[0]  ).groupby("id")["score"].mean().sort_index().values

p, diff, sig = significance_by_paired_ttest(scores_cot, scores_plain)
lo, mean, hi = ci_accuracy_for_difference(scores_cot, scores_plain)

print(f"CoT − plain: {mean:+.3f}  95% CI: [{lo:+.3f}, {hi:+.3f}]")
print(f"p-value    : {p:.4f}   significant @5%: {sig}")
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# CoT − plain: +0.116  95% CI: [+0.021, +0.212]
# p-value    : 0.0189   significant @5%: True

# %% [markdown]
# ---
# 1. Does chain-of-thought help? By how much, and is it significant?
# 2. Does the result surprise you? What might explain it?
# 3. Would you expect the same pattern on a different subject?
#
# **Your answer:**
# 1. CoT gain ≈ 0.116 pp; on n=112 anything under ~8 pp is likely non-significant given the MDE we computed.
# 2. Not very — small instruction-tuned models (Qwen-7B) often don't benefit much from CoT on short factual MCQs, since the bottleneck is knowledge, not reasoning chains.
# 3. Probably not uniformly — CoT tends to help more on reasoning-heavy subjects (math, logic, physics) and less on pure recall subjects (e.g. world religions, miscellaneous)

# %% [markdown]
# ## Bonus assignment: Clustered Standard Errors
#
# Some benchmarks contain groups of related questions — for example, several questions
# about the same passage in reading comprehension tasks like DROP or RACE. In such cases
# the standard CLT confidence interval is anti-conservative: questions within a group are
# correlated, so the effective sample size is smaller than n. Miller (2024) addresses this
# with clustered standard errors (§2.2).
#
# Using a reading comprehension benchmark of your choice, implement the clustered
# confidence interval (Eq. 4 from the paper) and compare it against the naive CLT interval.
# How much wider is the clustered interval? Does the difference depend on the benchmark?
# Then compare two models on the same benchmark using the clustered paired standard error
# (Eq. 8) — does the conclusion about which model is better change compared to the
# naive paired test?

# %%
# YOUR CODE HERE
